# %%
from requests_html import HTMLSession
from requests_html import HTML
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import csv
import re

# %%
def ThuThapData(link,maxNumPage,fileName):
    f = open(fileName, "a",encoding="utf-8")
    f.write("Loại\tTên\tCác loại phòng\tGiá\tVị trí\tSố đánh giá\n")
    browser = webdriver.Chrome(executable_path='chromedriver.exe')
    for page in range(1,maxNumPage+1):
        url = f"{link}{page}"
        browser.get(url)
        time.sleep(3)
        r = HTML(html=browser.page_source)
        posts=r.find(".promo.is-relative")
        for stt,post in enumerate(posts):
            temp=post.text.split("\n")
            # Bỏ đi dòng khuyến mãi
            if temp[0][0]=='-':
                temp.remove(temp[0])
            # Bỏ đi trạng thái phòng
            if 'Đặt phòng ngay' in temp[1]:
                temp.remove(temp[1])
            for i in temp:
                f.write(i)
                f.write("\t")
    f.write(link)
    f.write("\t")
    f.write("\n")
    f.close()

# %%
#ThuThapData("https://www.luxstay.com/vi/vietnam/lam-dong/da-lat?page=",71,"dalat.csv")
#ThuThapData("https://www.luxstay.com/vi/vietnam/ha-noi?page=",93,"hanoi.csv")
#ThuThapData("https://www.luxstay.com/vi/vietnam/ho-chi-minh?page=",134,"hochiminh.csv")
#ThuThapData("https://www.luxstay.com/vi/vietnam/ba-ria-vung-tau/vung-tau?page=",31,"vungtau.csv")
#ThuThapData("https://www.luxstay.com/vi/vietnam/khanh-hoa/nha-trang?page=",34,"nhatrang.csv")
#ThuThapData("https://www.luxstay.com/vi/vietnam/quang-ninh?page=",15,"quangninh.csv")

# %%
def crawDataOnePage(browser,url,time_sleep,file_name):
    browser.get(url)
    browser.execute_script("window.scrollTo(0, window.scrollY + 1200)")
    time.sleep(time_sleep)
    # Tắt quảng cáo bằng ESC nếu có
    browser.find_element_by_tag_name('html').send_keys(Keys.ESCAPE)
    r = HTML(html=browser.page_source)

    f = open(file_name, "a+",encoding="utf-8")
    f.write(url)
    f.write("\t")
    # Lấy tên nhà
    try:
        f.write(r.find(".col-xs-12.col-sm-10")[0].text)
    except:
        pass
    f.write("\t")
    # Lấy loại nhà
    try:
        f.write(r.find(".mt--12")[0].text.split(" · ")[0])
    except:
        pass
    f.write("\t")
    # Lấy Diện tích
    try:
        f.write(r.find(".mt--12")[0].text.split(" · ")[1])
    except:
        pass  
    f.write("\t")
    # Lấy các lại phòng
    try:
        f.write(r.find(".mb--0")[2].text)
    except:
        pass  
    f.write("\t")
    # Lấy giá phòng
    try:
        f.write(r.find(".fadeIn")[1].text)
    except:
        pass 
    f.write("\t")
    # Lấy ví trí
    try:
        f.write(r.find(".ml--6.bold")[0].text)
    except:
        pass 
    f.write("\t")
    #lấy tiện ích
    for i in range(10):
        try:
            x=browser.find_element_by_link_text("Xem thêm")
            x.click()
            reponse = HTML(html=browser.page_source)
            break
        except:
            pass
    try:
        f.write(reponse.find(".container.container--sm.pb--48")[0].text.replace("\n",",")) 
    except:
        pass
    f.write("\n")
    f.close()

# %%
def crawDataMulPage(main_link,time_sleep,file_name,startNumPage,endNumPage):
    pattern=r"^/vi/rooms/\d+"
    
    fi = open(file_name, "w",encoding="utf-8")
    fi.write("Link\tTên\tLoại nhà\tDiện tích\tCác loại phòng\tGiá\tVị trí\tTiện ích\n")
    fi.close()
    browser = webdriver.Chrome(executable_path='chromedriver.exe')
    for page in range(startNumPage,endNumPage):
        main_url = f"{main_link}{page}"
        #print(main_url)
        browser.get(main_url)
        time.sleep(time_sleep)
        r = HTML(html=browser.page_source)
        sub_links=[]
        # lọc link cần
        for link in r.links:
            if re.match(pattern,link)!=None:
                sub_links.append(link)
        #print(sub_links)
        # lấy data từng link
        for sub_link in sub_links:
            print(f"https://www.luxstay.com{sub_link}")
            crawDataOnePage(browser,f"https://www.luxstay.com{sub_link}",time_sleep,file_name)

# %%
crawDataMulPage("https://www.luxstay.com/vi/vietnam/quang-ninh?page=",1,"quangninh_p2.csv",15)
# Out:
# https://www.luxstay.com/vi/rooms/23335
# https://www.luxstay.com/vi/rooms/12140
# https://www.luxstay.com/vi/rooms/13396
# https://www.luxstay.com/vi/rooms/13140
# https://www.luxstay.com/vi/rooms/14511
# https://www.luxstay.com/vi/rooms/23107
# https://www.luxstay.com/vi/rooms/12334
# https://www.luxstay.com/vi/rooms/19664
# https://www.luxstay.com/vi/rooms/15113
# https://www.luxstay.com/vi/rooms/24604
# https://www.luxstay.com/vi/rooms/24281
# https://www.luxstay.com/vi/rooms/14085
# https://www.luxstay.com/vi/rooms/14058
# https://www.luxstay.com/vi/rooms/13844
# https://www.luxstay.com/vi/rooms/14252
# https://www.luxstay.com/vi/rooms/23537
# https://www.luxstay.com/vi/rooms/30756
# https://www.luxstay.com/vi/rooms/12963
# https://www.luxstay.com/vi/rooms/19359
# https://www.luxstay.com/vi/rooms/27755
# https://www.luxstay.com/vi/rooms/29278
# https://www.luxstay.com/vi/rooms/25748
# https://www.luxstay.com/vi/rooms/28429
# https://www.luxstay.com/vi/rooms/35342
# https://www.luxstay.com/vi/rooms/12684
# https://www.luxstay.com/vi/rooms/17512
# https://www.luxstay.com/vi/rooms/13857
# https://www.luxstay.com/vi/rooms/31524
# https://www.luxstay.com/vi/rooms/27179
# https://www.luxstay.com/vi/rooms/24020
# https://www.luxstay.com/vi/rooms/32622
# https://www.luxstay.com/vi/rooms/26528
# https://www.luxstay.com/vi/rooms/30912
# https://www.luxstay.com/vi/rooms/32758
# https://www.luxstay.com/vi/rooms/37303
# https://www.luxstay.com/vi/rooms/33764
# https://www.luxstay.com/vi/rooms/37354
# https://www.luxstay.com/vi/rooms/17511
# https://www.luxstay.com/vi/rooms/30851
# https://www.luxstay.com/vi/rooms/13399
# https://www.luxstay.com/vi/rooms/28589
# https://www.luxstay.com/vi/rooms/35502
# https://www.luxstay.com/vi/rooms/12635
# https://www.luxstay.com/vi/rooms/17513
# https://www.luxstay.com/vi/rooms/27484
# https://www.luxstay.com/vi/rooms/27756
# https://www.luxstay.com/vi/rooms/32765
# https://www.luxstay.com/vi/rooms/30817
# https://www.luxstay.com/vi/rooms/14585
# https://www.luxstay.com/vi/rooms/26991
# https://www.luxstay.com/vi/rooms/12861
# https://www.luxstay.com/vi/rooms/35650
# https://www.luxstay.com/vi/rooms/26866
# https://www.luxstay.com/vi/rooms/17529
# https://www.luxstay.com/vi/rooms/25758
# https://www.luxstay.com/vi/rooms/14901
# https://www.luxstay.com/vi/rooms/17514
# https://www.luxstay.com/vi/rooms/22532
# https://www.luxstay.com/vi/rooms/30378
# https://www.luxstay.com/vi/rooms/17154
# https://www.luxstay.com/vi/rooms/14013
# https://www.luxstay.com/vi/rooms/26806
# https://www.luxstay.com/vi/rooms/13862
# https://www.luxstay.com/vi/rooms/35742
# https://www.luxstay.com/vi/rooms/14956
# https://www.luxstay.com/vi/rooms/14550
# https://www.luxstay.com/vi/rooms/31508
# https://www.luxstay.com/vi/rooms/26704
# https://www.luxstay.com/vi/rooms/27738
# https://www.luxstay.com/vi/rooms/30264
# https://www.luxstay.com/vi/rooms/25920
# https://www.luxstay.com/vi/rooms/24211
# https://www.luxstay.com/vi/rooms/35931
# https://www.luxstay.com/vi/rooms/13734
# https://www.luxstay.com/vi/rooms/37023
# https://www.luxstay.com/vi/rooms/28458
# https://www.luxstay.com/vi/rooms/24900
# https://www.luxstay.com/vi/rooms/26209
# https://www.luxstay.com/vi/rooms/34789
# https://www.luxstay.com/vi/rooms/13139
# https://www.luxstay.com/vi/rooms/12769
# https://www.luxstay.com/vi/rooms/36425
# https://www.luxstay.com/vi/rooms/25554
# https://www.luxstay.com/vi/rooms/29503
# https://www.luxstay.com/vi/rooms/24523
# https://www.luxstay.com/vi/rooms/12612
# https://www.luxstay.com/vi/rooms/17517
# https://www.luxstay.com/vi/rooms/30752
# https://www.luxstay.com/vi/rooms/28488
# https://www.luxstay.com/vi/rooms/28315
# https://www.luxstay.com/vi/rooms/25678
# https://www.luxstay.com/vi/rooms/26661
# https://www.luxstay.com/vi/rooms/33502
# https://www.luxstay.com/vi/rooms/32063
# https://www.luxstay.com/vi/rooms/28525
# https://www.luxstay.com/vi/rooms/21667
# https://www.luxstay.com/vi/rooms/33937
# https://www.luxstay.com/vi/rooms/17530
# https://www.luxstay.com/vi/rooms/30931
# https://www.luxstay.com/vi/rooms/36424
# https://www.luxstay.com/vi/rooms/30348
# https://www.luxstay.com/vi/rooms/33931
# https://www.luxstay.com/vi/rooms/33942
# https://www.luxstay.com/vi/rooms/31619
# https://www.luxstay.com/vi/rooms/26996
# https://www.luxstay.com/vi/rooms/28742
# https://www.luxstay.com/vi/rooms/33941
# https://www.luxstay.com/vi/rooms/33857
# https://www.luxstay.com/vi/rooms/32555
# https://www.luxstay.com/vi/rooms/15450
# https://www.luxstay.com/vi/rooms/32583
# https://www.luxstay.com/vi/rooms/29281
# https://www.luxstay.com/vi/rooms/29245
# https://www.luxstay.com/vi/rooms/27218
# https://www.luxstay.com/vi/rooms/29282
# https://www.luxstay.com/vi/rooms/35501
# https://www.luxstay.com/vi/rooms/35279
# https://www.luxstay.com/vi/rooms/27863
# https://www.luxstay.com/vi/rooms/31746
# https://www.luxstay.com/vi/rooms/12863
# https://www.luxstay.com/vi/rooms/17518
# https://www.luxstay.com/vi/rooms/17526
# https://www.luxstay.com/vi/rooms/15510
# https://www.luxstay.com/vi/rooms/27899
# https://www.luxstay.com/vi/rooms/33405
# https://www.luxstay.com/vi/rooms/33074
# https://www.luxstay.com/vi/rooms/29784
# https://www.luxstay.com/vi/rooms/29866
# https://www.luxstay.com/vi/rooms/33409
# https://www.luxstay.com/vi/rooms/35832
# https://www.luxstay.com/vi/rooms/13735
# https://www.luxstay.com/vi/rooms/17524
# https://www.luxstay.com/vi/rooms/35743
# https://www.luxstay.com/vi/rooms/14873
# https://www.luxstay.com/vi/rooms/14086
# https://www.luxstay.com/vi/rooms/26079
# https://www.luxstay.com/vi/rooms/22911
# https://www.luxstay.com/vi/rooms/14958
# https://www.luxstay.com/vi/rooms/14089
# https://www.luxstay.com/vi/rooms/32621
# https://www.luxstay.com/vi/rooms/28992
# https://www.luxstay.com/vi/rooms/30715
# https://www.luxstay.com/vi/rooms/14084
# https://www.luxstay.com/vi/rooms/12552
# https://www.luxstay.com/vi/rooms/17211
# https://www.luxstay.com/vi/rooms/17213
# https://www.luxstay.com/vi/rooms/30617
# https://www.luxstay.com/vi/rooms/27841
# https://www.luxstay.com/vi/rooms/13859
# https://www.luxstay.com/vi/rooms/14082
# https://www.luxstay.com/vi/rooms/30905
# https://www.luxstay.com/vi/rooms/28780
# https://www.luxstay.com/vi/rooms/11445
# https://www.luxstay.com/vi/rooms/25924
# https://www.luxstay.com/vi/rooms/14079
# https://www.luxstay.com/vi/rooms/26513
# https://www.luxstay.com/vi/rooms/27367
# https://www.luxstay.com/vi/rooms/35497
# https://www.luxstay.com/vi/rooms/26997
# https://www.luxstay.com/vi/rooms/28591
# https://www.luxstay.com/vi/rooms/33945
# https://www.luxstay.com/vi/rooms/34825
# https://www.luxstay.com/vi/rooms/35503
# https://www.luxstay.com/vi/rooms/34831
# https://www.luxstay.com/vi/rooms/30751
# https://www.luxstay.com/vi/rooms/31820
# https://www.luxstay.com/vi/rooms/16868
# https://www.luxstay.com/vi/rooms/35671
# https://www.luxstay.com/vi/rooms/14837
# https://www.luxstay.com/vi/rooms/31697
# https://www.luxstay.com/vi/rooms/34791
# https://www.luxstay.com/vi/rooms/23633
# https://www.luxstay.com/vi/rooms/12455
# https://www.luxstay.com/vi/rooms/26600
# https://www.luxstay.com/vi/rooms/30643
# https://www.luxstay.com/vi/rooms/37008
# https://www.luxstay.com/vi/rooms/12154
# https://www.luxstay.com/vi/rooms/35504
# https://www.luxstay.com/vi/rooms/34951
# https://www.luxstay.com/vi/rooms/12476
# https://www.luxstay.com/vi/rooms/25437
# https://www.luxstay.com/vi/rooms/31313
# https://www.luxstay.com/vi/rooms/13341
# https://www.luxstay.com/vi/rooms/25809
# https://www.luxstay.com/vi/rooms/13843
# https://www.luxstay.com/vi/rooms/15073
# https://www.luxstay.com/vi/rooms/23707
# https://www.luxstay.com/vi/rooms/23253
# https://www.luxstay.com/vi/rooms/22313
# https://www.luxstay.com/vi/rooms/15931
# https://www.luxstay.com/vi/rooms/13883
# https://www.luxstay.com/vi/rooms/34178
# https://www.luxstay.com/vi/rooms/28539
# https://www.luxstay.com/vi/rooms/14075
# https://www.luxstay.com/vi/rooms/26421
# https://www.luxstay.com/vi/rooms/19906
# https://www.luxstay.com/vi/rooms/13324
# https://www.luxstay.com/vi/rooms/19521
# https://www.luxstay.com/vi/rooms/21913
# https://www.luxstay.com/vi/rooms/32958
# https://www.luxstay.com/vi/rooms/23705
# https://www.luxstay.com/vi/rooms/15795
# https://www.luxstay.com/vi/rooms/35429
# https://www.luxstay.com/vi/rooms/20900
# https://www.luxstay.com/vi/rooms/36559
# https://www.luxstay.com/vi/rooms/19770
# https://www.luxstay.com/vi/rooms/16694
# https://www.luxstay.com/vi/rooms/24363
# https://www.luxstay.com/vi/rooms/26308
# https://www.luxstay.com/vi/rooms/28880
# https://www.luxstay.com/vi/rooms/36423
# https://www.luxstay.com/vi/rooms/11679
# https://www.luxstay.com/vi/rooms/14505
# https://www.luxstay.com/vi/rooms/20078
# https://www.luxstay.com/vi/rooms/33984
# https://www.luxstay.com/vi/rooms/12442
# https://www.luxstay.com/vi/rooms/26259
# https://www.luxstay.com/vi/rooms/29699
# https://www.luxstay.com/vi/rooms/34788
# https://www.luxstay.com/vi/rooms/27167
# https://www.luxstay.com/vi/rooms/14154
# https://www.luxstay.com/vi/rooms/15169
# https://www.luxstay.com/vi/rooms/15493
# https://www.luxstay.com/vi/rooms/21224
# https://www.luxstay.com/vi/rooms/30923
# https://www.luxstay.com/vi/rooms/28825
# https://www.luxstay.com/vi/rooms/24753
# https://www.luxstay.com/vi/rooms/15820
# https://www.luxstay.com/vi/rooms/14762
# https://www.luxstay.com/vi/rooms/29577
# https://www.luxstay.com/vi/rooms/14623
# https://www.luxstay.com/vi/rooms/12090
# https://www.luxstay.com/vi/rooms/23834
# https://www.luxstay.com/vi/rooms/36629
# https://www.luxstay.com/vi/rooms/14769
# https://www.luxstay.com/vi/rooms/15287
# https://www.luxstay.com/vi/rooms/33099
# https://www.luxstay.com/vi/rooms/29889
# https://www.luxstay.com/vi/rooms/23579
# https://www.luxstay.com/vi/rooms/14130
# https://www.luxstay.com/vi/rooms/13733
# https://www.luxstay.com/vi/rooms/33944
# https://www.luxstay.com/vi/rooms/30948
# https://www.luxstay.com/vi/rooms/24424
# https://www.luxstay.com/vi/rooms/26846
# https://www.luxstay.com/vi/rooms/23895
# https://www.luxstay.com/vi/rooms/14182
# https://www.luxstay.com/vi/rooms/12679
# https://www.luxstay.com/vi/rooms/14732
# https://www.luxstay.com/vi/rooms/24326
# https://www.luxstay.com/vi/rooms/25722
# https://www.luxstay.com/vi/rooms/15672
# https://www.luxstay.com/vi/rooms/12554
# https://www.luxstay.com/vi/rooms/23719
# https://www.luxstay.com/vi/rooms/27284
# https://www.luxstay.com/vi/rooms/12924
# https://www.luxstay.com/vi/rooms/23413
# https://www.luxstay.com/vi/rooms/21103
# https://www.luxstay.com/vi/rooms/12549
# https://www.luxstay.com/vi/rooms/17246
# https://www.luxstay.com/vi/rooms/14245
# https://www.luxstay.com/vi/rooms/12625
# https://www.luxstay.com/vi/rooms/13244
# https://www.luxstay.com/vi/rooms/22388
# https://www.luxstay.com/vi/rooms/29472
# https://www.luxstay.com/vi/rooms/14535
# https://www.luxstay.com/vi/rooms/12095
# https://www.luxstay.com/vi/rooms/14351
# https://www.luxstay.com/vi/rooms/23058
# https://www.luxstay.com/vi/rooms/14962
# https://www.luxstay.com/vi/rooms/32759
# https://www.luxstay.com/vi/rooms/22077
# https://www.luxstay.com/vi/rooms/15445
# https://www.luxstay.com/vi/rooms/22370
# https://www.luxstay.com/vi/rooms/14744
# https://www.luxstay.com/vi/rooms/22780
# https://www.luxstay.com/vi/rooms/15480
# https://www.luxstay.com/vi/rooms/14658
# https://www.luxstay.com/vi/rooms/16864
# https://www.luxstay.com/vi/rooms/17010
# https://www.luxstay.com/vi/rooms/12551
# https://www.luxstay.com/vi/rooms/12678
# https://www.luxstay.com/vi/rooms/19610
# https://www.luxstay.com/vi/rooms/34785
# https://www.luxstay.com/vi/rooms/26320
# https://www.luxstay.com/vi/rooms/25771
# https://www.luxstay.com/vi/rooms/15075
# https://www.luxstay.com/vi/rooms/14660
# https://www.luxstay.com/vi/rooms/26832
# https://www.luxstay.com/vi/rooms/15453
# https://www.luxstay.com/vi/rooms/26840
# https://www.luxstay.com/vi/rooms/17528
# https://www.luxstay.com/vi/rooms/17519
# https://www.luxstay.com/vi/rooms/25843
# https://www.luxstay.com/vi/rooms/20214
# https://www.luxstay.com/vi/rooms/14957
# https://www.luxstay.com/vi/rooms/37589
# https://www.luxstay.com/vi/rooms/26184
# https://www.luxstay.com/vi/rooms/14659
# https://www.luxstay.com/vi/rooms/17212
